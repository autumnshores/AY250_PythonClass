# %%
# %pylab
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: MacOSX].
# For more information, type 'help(pylab)'.

# %%
#load flowers.csv dataset
dt = [('sepal length', np.float64), ('sepal width', np.float64), ('petal length', np.float64), ('petal width', np.float64), ('species', (str,10))]
data = np.loadtxt('flowers.csv',dt,delimiter=',',skiprows=1)

#plot 4x4 grid
f = plt.figure() 

#add 1st row of 4 subplots
ax11 = f.add_subplot(4, 4, 1)
ax11.set_ylim([4,8])
ax11.set_xlim([4,8])
ax11.text(4.5,7.0,'Sepal Length',fontsize='8')
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax11.scatter(data[i][0],data[i][0],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax11.scatter(data[i][0],data[i][0],color='#3cb371')
    if data[i][4] == 'virginica':
        ax11.scatter(data[i][0],data[i][0],color='#191970')
    i += 1
ax12 = f.add_subplot(4, 4, 2,sharey=ax11)
ax12.set_ylim([4,8])
ax12.set_xlim([2.,4.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax12.scatter(data[i][1],data[i][0],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax12.scatter(data[i][1],data[i][0],color='#3cb371')
    if data[i][4] == 'virginica':
        ax12.scatter(data[i][1],data[i][0],color='#191970')
    i += 1
ax13 = f.add_subplot(4, 4, 3,sharey=ax11)
ax13.set_ylim([4,8])
ax13.set_xlim([1,7])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax13.scatter(data[i][2],data[i][0],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax13.scatter(data[i][2],data[i][0],color='#3cb371')
    if data[i][4] == 'virginica':
        ax13.scatter(data[i][2],data[i][0],color='#191970')
    i += 1
ax14 = f.add_subplot(4, 4, 4,sharey=ax11)
ax14.set_ylim([4,8])
ax14.set_xlim([0.,2.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax14.scatter(data[i][3],data[i][0],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax14.scatter(data[i][3],data[i][0],color='#3cb371')
    if data[i][4] == 'virginica':
        ax14.scatter(data[i][3],data[i][0],color='#191970')
    i += 1
    
plt.setp(ax12.get_yticklabels(), visible=False)
plt.setp(ax13.get_yticklabels(), visible=False)
plt.setp(ax14.get_yticklabels(), visible=False)

#add 2nd row of 4 subplots
ax21 = f.add_subplot(4, 4, 5,sharex=ax11)
ax21.set_ylim([2.,4.5])
ax21.set_xlim([4,8])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax21.scatter(data[i][0],data[i][1],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax21.scatter(data[i][0],data[i][1],color='#3cb371')
    if data[i][4] == 'virginica':
        ax21.scatter(data[i][0],data[i][1],color='#191970')
    i += 1
ax22 = f.add_subplot(4, 4, 6,sharey=ax21,sharex=ax12)
ax22.set_ylim([2.,4.5])
ax22.set_xlim([2.,4.5])
ax22.text(2.2,4.0,'Sepal Width',fontsize='8')
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax22.scatter(data[i][1],data[i][1],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax22.scatter(data[i][1],data[i][1],color='#3cb371')
    if data[i][4] == 'virginica':
        ax22.scatter(data[i][1],data[i][1],color='#191970')
    i += 1
ax23 = f.add_subplot(4, 4, 7,sharey=ax21,sharex=ax13)
ax23.set_ylim([2.,4.5])
ax23.set_xlim([1,7])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax23.scatter(data[i][2],data[i][1],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax23.scatter(data[i][2],data[i][1],color='#3cb371')
    if data[i][4] == 'virginica':
        ax23.scatter(data[i][2],data[i][1],color='#191970')
    i += 1
ax24 = f.add_subplot(4, 4, 8,sharey=ax21,sharex=ax14)
ax24.set_ylim([2.,4.5])
ax24.set_xlim([0.,2.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax24.scatter(data[i][3],data[i][1],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax24.scatter(data[i][3],data[i][1],color='#3cb371')
    if data[i][4] == 'virginica':
        ax24.scatter(data[i][3],data[i][1],color='#191970')
    i += 1
    
plt.setp(ax22.get_yticklabels(), visible=False)
plt.setp(ax23.get_yticklabels(), visible=False)
plt.setp(ax24.get_yticklabels(), visible=False)

#add 3rd row of 4 subplots
ax31 = f.add_subplot(4, 4, 9,sharex=ax11)
ax31.set_ylim([1,7])
ax31.set_xlim([4,8])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax31.scatter(data[i][0],data[i][2],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax31.scatter(data[i][0],data[i][2],color='#3cb371')
    if data[i][4] == 'virginica':
        ax31.scatter(data[i][0],data[i][2],color='#191970')
    i += 1
ax32 = f.add_subplot(4, 4, 10,sharey=ax31,sharex=ax12)
ax32.set_ylim([1,7])
ax32.set_xlim([2.,4.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax32.scatter(data[i][1],data[i][2],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax32.scatter(data[i][1],data[i][2],color='#3cb371')
    if data[i][4] == 'virginica':
        ax32.scatter(data[i][1],data[i][2],color='#191970')
    i += 1
ax33 = f.add_subplot(4, 4, 11,sharey=ax31,sharex=ax13)
ax33.set_ylim([1,7])
ax33.set_xlim([1,7])
ax33.text(1.2,6.0,'Petal Length',fontsize='8')
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax33.scatter(data[i][2],data[i][2],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax33.scatter(data[i][2],data[i][2],color='#3cb371')
    if data[i][4] == 'virginica':
        ax33.scatter(data[i][2],data[i][2],color='#191970')
    i += 1
ax34 = f.add_subplot(4, 4, 12,sharey=ax31,sharex=ax14)
ax34.set_ylim([1,7])
ax34.set_xlim([0.,2.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax34.scatter(data[i][3],data[i][2],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax34.scatter(data[i][3],data[i][2],color='#3cb371')
    if data[i][4] == 'virginica':
        ax34.scatter(data[i][3],data[i][2],color='#191970')
    i += 1
    
plt.setp(ax32.get_yticklabels(), visible=False)
plt.setp(ax33.get_yticklabels(), visible=False)
plt.setp(ax34.get_yticklabels(), visible=False)

#add 4th row of 4 subplots
ax41 = f.add_subplot(4, 4, 13,sharex=ax11)
ax41.set_ylim([0.,2.5])
ax41.set_xlim([4,8])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax41.scatter(data[i][0],data[i][3],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax41.scatter(data[i][0],data[i][3],color='#3cb371')
    if data[i][4] == 'virginica':
        ax41.scatter(data[i][0],data[i][3],color='#191970')
    i += 1
ax42 = f.add_subplot(4, 4, 14,sharey=ax41,sharex=ax12)
ax42.set_ylim([0.,2.5])
ax42.set_xlim([2.,4.5])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax42.scatter(data[i][1],data[i][3],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax42.scatter(data[i][1],data[i][3],color='#3cb371')
    if data[i][4] == 'virginica':
        ax42.scatter(data[i][1],data[i][3],color='#191970')
    i += 1
ax43 = f.add_subplot(4, 4, 15,sharey=ax41,sharex=ax13)
ax43.set_ylim([0.,2.5])
ax43.set_xlim([1,7])
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax43.scatter(data[i][2],data[i][3],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax43.scatter(data[i][2],data[i][3],color='#3cb371')
    if data[i][4] == 'virginica':
        ax43.scatter(data[i][2],data[i][3],color='#191970')
    i += 1
ax44 = f.add_subplot(4, 4, 16,sharey=ax41,sharex=ax14)
ax44.set_ylim([0.,2.5])
ax44.set_xlim([0.,2.5])
ax44.text(0.1,2.2,'Petal Width',fontsize='8')
i = 0
while i < len(data):
    if data[i][4] == 'setosa':
        ax44.scatter(data[i][3],data[i][3],color='#a52a2a')
    if data[i][4] == 'versicolor':
        ax44.scatter(data[i][3],data[i][3],color='#3cb371')
    if data[i][4] == 'virginica':
        ax44.scatter(data[i][3],data[i][3],color='#191970')
    i += 1
    
plt.setp(ax42.get_yticklabels(), visible=False)
plt.setp(ax43.get_yticklabels(), visible=False)
plt.setp(ax44.get_yticklabels(), visible=False)

plt.setp(ax11.get_xticklabels(), visible=False)
plt.setp(ax21.get_xticklabels(), visible=False)
plt.setp(ax31.get_xticklabels(), visible=False)
plt.setp(ax12.get_xticklabels(), visible=False)
plt.setp(ax22.get_xticklabels(), visible=False)
plt.setp(ax32.get_xticklabels(), visible=False)
plt.setp(ax13.get_xticklabels(), visible=False)
plt.setp(ax23.get_xticklabels(), visible=False)
plt.setp(ax33.get_xticklabels(), visible=False)
plt.setp(ax14.get_xticklabels(), visible=False)
plt.setp(ax24.get_xticklabels(), visible=False)
plt.setp(ax34.get_xticklabels(), visible=False)
# Out:
# [None, None, None, None, None, None]

# %%
#interactively draw a rectangle and get axis coordinates of the rectangle
from matplotlib.patches import Rectangle

class Annotate(object):
    def __init__(self):
        self.ax = plt.gca()
        self.rect = Rectangle((0,0), 1, 1,facecolor='None', edgecolor='k')
        self.x0 = None
        self.y0 = None
        self.x1 = None
        self.y1 = None
        self.ax.figure.canvas.mpl_connect('button_press_event', self.on_press)
        self.ax.figure.canvas.mpl_connect('motion_notify_event', self.on_motion)
        self.ax.figure.canvas.mpl_connect('button_release_event', self.on_release)

    def on_press(self, event):
        print 'press'
        self.x0 = event.xdata
        self.y0 = event.ydata
        print self.x0
        print self.y0
        
    def on_motion(self,event):
        if self.on_press is True:
            return
        self.x1 = event.xdata
        self.y1 = event.ydata
        self.rect.set_width(self.x1 - self.x0)
        self.rect.set_height(self.y1 - self.y0)
        self.rect.set_xy((self.x0, self.y0))
        self.rect.set_linestyle('dashed')
        self.ax.figure.canvas.draw()

    def on_release(self, event):
        print 'release'
        self.x1 = event.xdata
        self.y1 = event.ydata
        self.rect.set_width(self.x1 - self.x0)
        self.rect.set_height(self.y1 - self.y0)
        self.rect.set_xy((self.x0, self.y0))
        self.ax.figure.canvas.draw()
        self.ax.add_patch(self.rect)
        print self.x1
        print self.y1

a = Annotate()
plt.show()
# Out:
# press
# 0.169126431935
# 1.64475508318
# release
# 1.83403612341
# 0.395910351201
# press
# 1.86636446693
# 0.581908502773
# release
# 1.86636446693
# 0.581908502773
# press
